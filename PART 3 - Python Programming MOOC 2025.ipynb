# %% [markdown]
# Start Selasa, 4 Februari 2025, 12:02 PM
#
# # Part 3 - Working with Strings
#
# * Learning objectives
# After this section
#
# You will be able to use the operators + and * with strings
# You will know how to find out the length of a string
# You will know what is meant by string indexing
# You will know how to look for substrings within a string
#
# * String operations
# Strings can be combined, or concatenated, with the + operator:
#
# begin = "ex"
# end = "ample"
# word = begin+end
# print(word)
# output : example
#
#
# The * operator can also be used with a string, when the other operand is an integer. The string operand is then repeated the number of times specified by the integer. For example this would work:
#
# word = "banana"
# print(word*3)
# output : bananabananabanana
#
#
# Using string operations together with a loop we can write a program which draws a pyramid:
#
# n = 10 # number of layers in the pyramid
# row = "*"
#
# while n > 0:
#     print(" " * n + row)
#     row += "**"
#     n -= 1
#
# This prints out the following:
#
#           *             -> n = 10, row = *
#          ***            -> n = 9, row = ***
#         *****           -> n = 8, row = *****
#        *******          -> n = 7, row = *******
#       *********         -> n = 6, row = *********
#      ***********        -> n = 5, row = ***********
#     *************       -> n = 4, row = *************
#    ***************      -> n = 3, row = ***************
#   *****************     -> n = 2, row = *****************
#  *******************    -> n = 1, row = *******************
#
#
# The print command within the loop prints a line, which begins with n spaces, followed by whatever is stored in the variable row. Then two stars are added to the end of the variable row, and the value of the variable n is decreased by 1.

# %%
# Programming Exercise :
# String multiplied

'''
Please write a program which asks the user for a string and an amount. The program then prints out the string as many times as specified by the amount. 
The printout should all be on one line, with no extra spaces or symbols added.

An example of expected behaviour:
Please type in a string: hiya
Please type in an amount: 4
hiyahiyahiyahiya
'''

# ALGORITMA
'''
1. Mulai
2. Program minta input string ke user -> str(input("Please type in a string: )
3. User ngasih input string ke program 
4. Program minta user ngasih tau string-nya mau diprint berapa kali -> int(input("Please type in an amount: ")
5. User ngasih input integer berapa banyak string-nya mau diprint ke program
6. Program ngeprint string inputan user sebanyak yang diinginkan
7. Selesai
'''

kata = str(input("Please type in a string: "))
berapaBanyak = int(input("Please type in an amount: "))

print(f"{kata * berapaBanyak}")
# Out:
# testestes

# %% [markdown]
# Start Rabu, 5 Februari 2025, 06:29 AM
#
# # Part 3 - The length and index of a string
#
# The function len returns the number of characters in a string, which is always an integer value. For example, len("hey") returns 3, because there are three characters in the string hey.
#
# The following program asks the user for a string and then prints it "underlined". The program prints a second line with as many - characters as is the length of the input:
#
# input_string = input("Please type in a string: ")
# print(input_string)
# print("-"*len(input_string))
#
# Please type in a string: Hi there!
# Hi there!
#
#
# As strings are essentially sequences of characters, any single character in a string can also be retrieved. The operator [] finds the character with the index specified within the brackets.
#
# The index refers to a position in the string, counting up from zero. The first character in the string has index 0, the second character has index 1, and so forth.
#
# For example, this program
# input_string = input("Please type in a string: ")
# print(input_string[0])
# print(input_string[1])
# print(input_string[3])
#
# would print out this:
# Please type in a string: monkey
# m
# o
# k
#
# Since the first character in a string has the index 0, the last character has the index length - 1. The following program prints out the first and the last characters of a string:
#
# input_string = input("Please type in a string: ")
# print("First character: " + input_string[0])
# print("Last character: " + input_string[len(input_string) - 1])
#
# Please type in a string: testing
# First character: t
# Last character: g
#
#
# The following program loops through all the characters in a string from first to last:
#
# input_string = input("Please type in a string: ")
# index = 0
# while index < len(input_string):
#     print(input_string[index])
#     index += 1
#
# Please type in a string: test
# t
# e
# s
# t
#
# You can also use negative indexing to access characters counting from the end of the string. The last character in a string is at index -1, the second to last character is at index -2, and so forth. You can think of input_string[-1] as shorthand for input_string[len(input_string) - 1].
#
# The example from above can be simplified with negative indexing:
# input_string = input("Please type in a string: ")
# print("First character: " + input_string[0])
# print("Last character: " + input_string[-1])
#
# Please type in a string: testing
# First character: t
# Last character: g
#
# * IndexError: string index out of range
#
# If you tried the above examples for yourself, you may already have come across the error message IndexError: string index out of range. This error appears if you try to access an index which is not present in the string.
#
# input_string = input("Please type in a string: ")
# print("The tenth character: " + input_string[9])
#
# Please type in a string: introduction to programming
# The tenth character: i
#
# Please type in a string: python
# Traceback (most recent call last):
# File "", line 1, in
# IndexError: string index out of range
#
# Sometimes an indexing error is caused by a bug in the code. For example, it is quite common to index too far when trying to access the last character in a string:
# input_string = input("Please type in a string: ")
# print("Last character: " + input_string[len(input_string)])
#
# Since string indexing begins at zero, the last character is at index len(input_string) - 1, not at len(input_string).
#
# There are situations where the program should prepare for errors caused by input from the user:
# input_string = input("Please type in a string: ")
# if len(input_string) > 0:
#     print("First character: " + input_string[0])
# else:
#     print("The input string is empty. There is no first character.")
#
#
# In the example above, if the programmer hadn't included a check for the length of the input string, a string of length zero would have caused an error. A string of length zero is also called an empty string, and here it would be achieved by just pressing Enter at the input prompt.

# %%
# Programming Exercise :
# The longer string

'''
Please write a program which asks the user for two strings and then prints out whichever is the longer of the two - 
that is, whichever has the more characters. If the strings are of equal length, the program should print out 
"The strings are equally long".

Some examples of expected behaviour:
Please type in string 1: hey
Please type in string 2: hiya
hiya is longer

Please type in string 1: howdy doody
Please type in string 2: hola
howdy doody is longer

Please type in string 1: hey
Please type in string 2: bye
The strings are equally long
'''

# ALGORITMA
'''
1. Mulai
2. Program minta input string pertama ke user
    2.1 User input string pertama ke program
3. Program minta input string kedua ke user
    3.1 User input string kedua ke program
4. Program mengolah kedua input dari user
    4.1 Cek panjang string pertama dan kedua menggunakan len()
    4.2 If string pertama > string kedua, print(f"{string pertama} is longer)
        elif string pertama < string kedua, print(f"{string kedua} is longer)
        else, print("The strings are equally long)
5. Selesai
'''

stringPertama = input("Please type in string 1: ")
stringKedua = input("Please type in string 2: ")

panjangStringPertama = len(stringPertama)
panjangStringKedua = len(stringKedua)

if panjangStringPertama > panjangStringKedua:
    print(f"{stringPertama} is longer")
elif panjangStringPertama < panjangStringKedua:
    print(f"{stringKedua} is longer")
else:
    print("The strings are equally long")
# Out:
# ha ha is longer

# %%
# Programming Exercise :
# End to beginning

'''
Please write a program which asks the user for a string. The program then prints out the input string in reversed order, 
from end to beginning. Each character should be on a separate line.

An example of expected behaviour:
Please type in a string: hiya
a
y
i
h
'''

# ALGORITMA
'''
1. Mulai
    1.1 definisikan index = -1
2. Program minta input string ke user -> kata = input("Please type in a string: ")
3. User ngasih input string ke program
4. Program mengolah inputan string dari user
    4.1 WHILE index < 0:
        print(kata[index])
        index -= 1
        if len(kata) - index == 0:
            break
5. Selesai

REVISI 
    4.1 WHILE index >= -len(kata):  -> Gausah pake if lagi kalo udah kaya gini, nanti ketika indexnya makin mengecil, suatu
    saat dia bakal kurang dari si -len(kata), yang menyebabkan kondisi while-nya ngga terpenuhi lagi (berhenti loopnya)
        print(kata[index])
        index -= 1
'''
index = -1
kata = input("Please type in a string: ")

while index >= -len(kata):
    print(kata[index])
    index -= 1
# Out:
# a
# y
# i
# h

# %% [markdown]
# Start Kamis, 6 Februari 2025, 08:12 PM

# %%
# Programming Exercise :
# Second and second to last characters

'''
Please write a program which asks the user for a string. The program then prints out a message based on whether the second character and 
the second to last character are the same or not. See the examples below.

Please type in a string: python
The second and the second to last characters are different

Please type in a string: pascal
The second and the second to last characters are a
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai
2. Program minta input string dari user -> kata = input("Please type in a string: ")
3. User memberikan input string ke program
    3.1 definisikan karakterKedua = kata[1]  --> kenapa kata[1], kan karakter kedua?  jangan lupa index dimulai dari 0, maka karakter kedua dari awal ada di indeks[1]
4. Program mengolah inputan string dari user dengan mengecek apakah karakter kedua pertama dan kedua terakhir sama atau tidak.
    4.1 IF kata[1] == kata [-2]:
            print(f"The second and the second to last characters are {karakterKedua})
        ELSE :
            print("The second and the second to last characters are different")
5. Selesai
'''

kata = input("Please type in a string: ")
karakterKedua = kata[1]

if kata[1] == kata[-2]:
    print(f"The second and the second to last characters are {karakterKedua}")
else:
    print(f"The second and the second to last characters are different")
# Out:
# The second and the second to last characters are a

# %%
# Programming Exercise :
# A line of hashes

'''
Please write a program which prints out a line of hash characters, the width of which is chosen by the user.

Width: 3
###

Width: 8
########
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program buat ngeprint tanda pager sebanyak yang user mau
2. Program minta input banyakTagar ke user -> banyakTagar = int(input("Width: "))
3. User input banyakTagar ke program
4. Program mengolah inputan banyakTagar dari user
    4.1 print(f" '#' * {banyakTagar}")
5. Selesai

REVISI

    4.1 print(f" '#' * {banyakTagar}") -> print("#" * banyakTagar), karena tujuan kita kan bukan mau nampilin sebuah variabel
    ke dalam print.  Tujuan kita cuman mau mengalikan sebuah string("#") sebanyak banyakTagar.
'''
banyakTagar = int(input("Width: "))
print("#" * banyakTagar)
# Out:
# ##############

# %%
# Programming Exercise :
# A rectangle of hashes

'''
Please modify the previous program so that it also asks for the height, and prints out a rectangle of hash characters accordingly.

Width: 10
Height: 3
##########
##########
##########
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program buat ngeprint tanda pager sebanyak panjang dan tinggi yang user mau
    1.1 buat variabel tinggiPagarAkhir buat keperluan loopnya -> tinggiPagarAkhir = 1
2. Program minta input panjang tanda pager ke user -> panjangPagar = int(input("Width: "))
    2.1 User ngasih input panjangPagar ke program
3. Program minta input tinggi tanda pager ke user -> tinggiPagar = int(input("Height: ))
    3.1 User ngasih input tinggiPagar ke program
4. Program mengolah input panjangPagar dan tinggiPagar dari user
    4.1 while panjangPagar or tinggiPagar != 0 and tinggiPagarAkhir <= tinggiPagar:
            print("#" * panjangPagar)
            tinggiPagarAkhir = tinggiPagarAkhir + 1
5. Selesai

Jadi, pada iterasi ke-1, program bakal ngeprint panjangPagar-nya dulu.  
Nah, nanti kan iterasi ke-2, pas si tinggiPagarAkhir-nya jadi 2, program ngeprint lagi panjangPagar-nya
Gitu terus sampai si tinggiPagarAkhir-nya melebihi tinggiPagar, program bakal berhenti.


REVISI

4.1 while panjangPagar or tinggiPagar != 0 and tinggiPagarAkhir <= tinggiPagar:

Jangan lupa dalam kurungnya biar ngga ambigu -> while (panjangPagar or tinggiPagar != 0) and tinggiPagarAkhir <= tinggiPagar:
'''

tinggiPagarAkhir = 1
panjangPagar = int(input("Width: "))
tinggiPagar = int(input("Height: "))

while (panjangPagar or tinggiPagar != 0) and tinggiPagarAkhir <= tinggiPagar:
    print("#" * panjangPagar)
    tinggiPagarAkhir += 1
# Out:
# ##########
# ##########
# ##########

# %%
# Programming Exercise :
# Underlining

'''
Please write a program which asks the user for strings using a loop. 
The program prints out each string underlined as shown in the examples below. 
The execution ends when the user inputs an empty string - that is, just presses Enter at the prompt.

Please type in a string: Hi there!
Hi there!
---------

Please type in a string: This is a test
This is a test
--------------

Please type in a string: a
a
-

Please type in a string:
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program buat ngeprint tanda strip(-) sebanyak karakter string yang user input
    1.1 definisikan string kosong buat kondisi di loop -> stringKosong = ""
    1.2 definisikan input dummy buat perbandingan sama si stringKosong-> inputString = "tes" 
2. WHILE inputString != stringKosong:
        inputString = input("Please type in a string: ")
        print inputString
        print "-" * len(inputString)
3. Selesai
'''

stringKosong = ""
inputString = "tes"

while inputString != stringKosong:
    inputString = input("Please type in a string: ")
    print(inputString)
    print("-" * len(inputString))
# Out:
# tes123
# ------
# tes 1 2 3
# ---------
# tes1 2   3
# ----------
# t          e         s
# ----------------------

# %%
# Programming Exercise :
# Right-aligned

'''
Please write a program which asks the user for a string and then prints it out 
so that exactly 20 characters are displayed. If the input is shorter than 20 characters, 
the beginning of the line is filled in with * characters.

You may assume the input string is at most 20 characters long.

Please type in a string: python
**************python

Please type in a string: alongerstring
*******alongerstring

Please type in a string: averyverylongstring
*averyverylongstring
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Right-aligned
    1.1 definisikan string bintangFull (bintang sebanyak 20 karakter) 
    buat keperluan string finalnya nanti -> bintangFull = "********************"
2. Program minta input string ke user -> inputStringUser = input("Please type in a string: ")
3. Program mengolah inputStringUser
    3.1 Set kondisi program bakal jalan hanya JIKA inputStringUser-nya maksimal 20 karakter. 
            IF inputStringUser <= 20:
                panjangBintangPrint = len(bintangFull) - len(inputStringUser) -> buat ngeprint "*" sebanyak (20 karakter - karakter dari string inputan user)
                stringFinal = ("*" * panjangBintangPrint) + inputStringUser -> jadi nanti outputnya adalah bintang di depan sebanyak (20 karakter - karakter dari string inputan user)
                ditambah sama inputStringUser itu sendiri.
                print(stringFinal)
4. Selesai



REVISI 

IF inputStringUser <= 20: -> Jangan lupa tambahin len-nya, kan mau ngebandingin panjang karakter(int) sama 20(int)

jadinya IF len(inputStringUser <= 20: )
'''

bintangFull = "********************"
inputStringUser = input("Please type in a string: ")

if len(inputStringUser) <= 20:
    panjangBintangPrint = len(bintangFull) - len(inputStringUser)
    stringFinal = ("*" * panjangBintangPrint) + inputStringUser
    print(stringFinal)
# Out:
# *******************h

# %% [markdown]
# Start Sabtu, 8 Februari 2025, 02:03 AM

# %%
# Programming Exercise :
# A framed word

'''
Please write a program which asks the user for a string and then prints out a frame of * characters 
with the word in the centre. The width of the frame should be 30 characters. 
You may assume the input string will always fit inside the frame.

If the length of the input string is an odd number, you may print out the word in 
either of the two possible centre locations.

Word: testing
******************************
*          testing           *
******************************

Word: python
******************************
*           python           *
******************************
'''

# KOTRETAN KASAR
'''
berarti string yang di tengah maksimal 28 karakter karena di ujung kiri sama kanan ada satu bintang, jadi kan 30 - (1 *2)

misal stringnya 5 karakter:
    28 - 5 = 23 space kosong kanan + kiri -> bisa kanan 12, kiri 11 ATAU kanan 11, kiri 12
    print("******************************")
    print("*" + (" " * (23//2)) + string + (" " * ((23//2)+1)))
    print("******************************")

    
misal stringnya 4 karakter:
    28 - 4 = 24 space kosong kanan + kiri -> kanan 12, kiri 12
    print((" " * (24//2)) + string)

string = "haloo" -> String GANJIL
print("******************************")
print("*" + (" " * (23//2)) + string + (" " * ((23//2)+1) + "*"))
print("******************************")
OUTPUT:
******************************
*           haloo            *
******************************


string = "halo" -> String GENAP
print("******************************")
print("*" + (" " * (24//2)) + string + (" " * ((24//2)) + "*"))
print("******************************")
OUTPUT:
******************************
*            halo            *
******************************
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program A Framed Word
2. Definisikan beberapa variabel
    Karena kalo ngeprint itu per baris, maka framenya gabisa langsung dibentuk jadi kotak, harus per baris juga. MAKA
        2.1 Definisikan frame bintang atas -> frameAtas = "*" * 30
        2.2 Definisikan juga frame bintang bawah -> frameBawah = "*" * 30
        2.3 Barulah kita bentuk isi tengahnya
            2.3.1 Sisa space kosong di tengah buat nampilin string inputan user kan ada 28 karakter.  
                  Minta input user.  Berarti nanti input dari usernya harus <=28 biar masih muat.
            2.3.2 Abis itu kita bikin kondisional, kondisi pertama jika panjang karakter string inputan user genap,
                  Kondisi kedua jika panjang karakter string inputan user ganjil.
            2.3.3 Biar nanti ngeprintnya enak, gausah banyak notasi mtk dan angka, 
                  maka nanti buat variabel aja jarakKiri dan jarakKanan di kondisional pertama dan kedua
            2.3.4 Udah deh nanti tinggal diprint kaya gini -> print("*" + jarakKiri + string + jarakKanan + "*")
3. Selesai

REVISI

-> jangan lupa bikin variabel selisihSpaceDanString buat nentuin pembaginya
'''

frameAtas = frameBawah = "*" * 30
inputString = input("Word: ")
selisihSpaceDanString = 28 - len(inputString) 

if len(inputString) <= 28 and len(inputString) % 2 == 0:  #Kondisi 1 (JIKA panjang inputan string user GENAP)
    jarakKiri = jarakKanan = " " * (selisihSpaceDanString // 2) #Karena genap jadi space di kanan dan kirinya sama
    print(frameAtas)
    print("*" + jarakKiri + inputString + jarakKanan + "*")
    print(frameBawah)
    
elif len(inputString) <= 28 and len(inputString) % 2 != 0: #Kondisi 2 (JIKA panjang inputan string user GANJIL)
    jarakKiri = " " * (selisihSpaceDanString // 2) #Karena ganjil jadi spacenya bisa antara yang kiri kurang 1 dari yang di kanan atau sebaliknya; di sini pake yang di kiri kurang 1 dari yang di kanan aja
    jarakKanan = jarakKiri + " "
    print(frameAtas)
    print("*" + jarakKiri + inputString + jarakKanan + "*")
    print(frameBawah)
# Out:
# ******************************
# * tessssssssssssssssssssssss *
# ******************************

# %% [markdown]
# Start Sabtu, 8 Februari 2025, 03:05 AM
#
# # Part 3 - Substrings and slices
#
# * A substring of a string is a sequence of characters that forms a part of the string. For example, the string "example" contains the substrings exam, amp and ple, among others. In Python programming, "the process of selecting substrings is usually called slicing", and a substring is often referred to as a slice of the string. The two terms can often be used interchangeably.
#
# * If you know the beginning and end indexes of the slice you wish to extract, you can do so with the notation [a:b]. This means the slice begins at the index a and ends at the last character before index b - that is, including the first, but excluding the last. You can think of the indexes as separator lines drawn on the left side of the indexed character, as illustrated in the image below:
#
# String my_string = "Exemplary";
# my_string.substring(2,6) == "empl"
#
# * Let's have a closer look at some sliced strings:
# input_string = "presumptious"
#
# print(input_string[0:3]) -> pre
# print(input_string[4:10]) -> umptio
#
# if the beginning index is left out, it defaults to 0
# print(input_string[:3]) -> pre
#
# if the end index is left out, it defaults to the length of the string
# print(input_string[4:]) -> umptious
#
# * Half open intervals
# In Python string processing the interval [a:b] is half open, which in this case means that the character at the beginning index a is included in the interval, but the character at the end index b is left out. Why is that?
#
# There is no profound reason for this feature. Rather it is a convention inherited from other programming languages.
#
# Half open intervals may feel unintuitive, but in practice they do have some advantages. For example, you can easily calculate the length of a slice with b-a. On the other hand, you must always remember that the character at the end index b will not be included in the slice.
#
# * Gada alasan khusus kenapa intervalnya modelan inclusive [a:b], mulai dari a, berakhir sebelum b.  Tapi keuntungannya
# kita bisa dengan mudah nyari panjang karakter dengan tinggal ngitung b-a

# %%
# Programming Exercise :
# Substrings, part 1

'''
Please write a program which asks the user to type in a string. The program then 
prints out all the substrings which begin with the first character, from the shortest to the longest. 
Have a look at the example below.

Please type in a string: test
t
te
tes
test
'''

# KOTRETAN KASAR
'''
inputString = "tes"
x = 1
print(inputString[:x])
print(inputString[:2])
print(inputString[:3])

iterasi = 0
inputString = "tes"
while iterasi <= len(inputString):
    print(inputString[:iterasi])
    iterasi += 1
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Substrings, part 1
2. Definisikan variabel
    2.1 Variabel iterasi = 0 -> biar bisa dipake buat kondisi while-nya
3. Minta input string ke user -> inputString = input("Please type in a string: )
4. buat while loop-nya
    4.1 WHILE iterasi <= panjang karakter inputString:  //jadi ketika iterasinya udah melebihi panjang karakternya, bakal berhenti.
            print(inputString[:iterasi])  //bakal ngeprint substring dari :0 (karena iterasi pertama itu 0), dan seterusnya.
            iterasi += 1  //iterasi-nya bakal nambah 1 setiap cycle loop.
5. Selesai
'''

# KODE FIKS
iterasi = 0
inputString = input("Please type in a string: ")
while iterasi <= len(inputString):
    print(inputString[:iterasi])
    iterasi += 1
# Out:
# h
# ha
# hal
# halo
# haloo

# %%
# Programming Exercise :
# Substrings, part 2

'''
Please write a program which asks the user to type in a string. The program then prints out 
all the substrings which end with the last character, from the shortest to the longest. 
Have a look at the example below.

Please type in a string: test
t
st
est
test
'''

# KOTRETAN KASAR
'''
inputString = "tes123"
print(inputString[5:6])
print(inputString[4:6])
print(inputString[3:6])
print(inputString[2:6])
print(inputString[1:6])
print(inputString[0:6])

OUTPUT:
3
23
123
s123
es123
tes123
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Substrings, part 2
2. Program minta input string ke user -> inputString = input("Please type in a string: ")
3. User input string ke program
4. Definisiin variabel buat keperluan loopingnya nanti -> indeksMulai = len(inputString) - 1
5. Program ngolah inputan string user
    4.1 WHILE indeksMulai >= 0:
            print(inputString[indeksMulai:len(inputString)])
            indeksMulai -= 1
5. Selesai

Nah, jadi konsepnya kita ambil dari kotretan kasar.  Itu kan kalo kita print manual satu-satu kaya gitu caranya kurang efisien,
tapi dari situ kita bisa lihat polanya.  Misal anggap notasi == [a,b].  Ternyata, si "b" nya itu selalu tetap dan yang berubah
adalah "a".  "a" nya sendiri adalah indeks maksimum dari string, sedangkan "b" adalah panjang karakter dari string.  

Berdasarkan pola itu, yaudah berarti kita bikin kode yang berfokus ke perubahan si "a".  Kali ini, kita pakai WHILE loop biar
programnya lebih efisien.  Bayangin kalo kodenya manual kaya yang di kotretan kasar, agak susah semisal nanti stringnya panjang, kita harus 
ubah satu-satu.  Kalo pake loop gini kan kita tinggal minta user aja yang input apa string-nya, otomatis bakal diiterasi sama programnya.
'''

# KODE FIKS
inputString = input("Please type in a string: ")
indeksMulai = len(inputString) - 1
while indeksMulai >= 0:
    print(inputString[indeksMulai:len(inputString)])
    indeksMulai -= 1
# Out:
# t
# it
# lit
# elit
#  elit
# g elit
# ng elit
# ing elit
# cing elit
# scing elit
# iscing elit
# piscing elit
# ipiscing elit
# dipiscing elit
# adipiscing elit
#  adipiscing elit
# r adipiscing elit
# ur adipiscing elit
# tur adipiscing elit
# etur adipiscing elit
# tetur adipiscing elit
# ctetur adipiscing elit
# ectetur adipiscing elit
# sectetur adipiscing elit
# nsectetur adipiscing elit
# onsectetur adipiscing elit
# consectetur adipiscing elit
#  consectetur adipiscing elit
# , consectetur adipiscing elit
# t, consectetur adipiscing elit
# et, consectetur adipiscing elit
# met, consectetur adipiscing elit
# amet, consectetur adipiscing elit
#  amet, consectetur adipiscing elit
# t amet, consectetur adipiscing elit
# it amet, consectetur adipiscing elit
# sit amet, consectetur adipiscing elit
#  sit amet, consectetur adipiscing elit
# r sit amet, consectetur adipiscing elit
# or sit amet, consectetur adipiscing elit
# lor sit amet, consectetur adipiscing elit
# ...

# %% [markdown]
# Start Senin, 10 Februari 2025, 09:23 PM
#
# # Part 3 - Searching for substrings
#
# * The in operator can tell us if a string contains a particular substring. The Boolean expression a in b is true, if b contains the substring a.
#
# * For example, this bit of code
#
# input_string = "test"
#
# print("t" in input_string)
# print("x" in input_string)
# print("es" in input_string)
# print("ets" in input_string)
#
# OUTPUT :
# True -> karena ada huruf t di test
# False -> karena gaada huruf x di test
# True -> karena ada suku kata es di test
# False -> karena ga ada suku kata ets di test
#
#
# * The program below lets the user search for substrings within a string hardcoded into the program:
# input_string = "perpendicular"
#
# while True:
#     substring = input("What are you looking for? ")
#     if substring in input_string:
#         print("Found it")
#     else:
#         print("Not found")
#
# OUTPUT:
# What are you looking for? perp
# Found it
# What are you looking for? abc
# Not found
# What are you looking for? pen
# Found it
# ...

# %%
# Programming Exercise :
# Does it contain vowels (huruf vokal)
'''
Please write a program which asks the user to input a string. 
The program then prints out different messages if the string contains any of the vowels a, e or o.
You may assume the input will be in lowercase entirely. Have a look at the examples below.

Please type in a string: hello there
a not found
e found
o found

Please type in a string: hiya
a found
e not found
o not found
'''

# KOTRETAN KASAR
'''
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Does it Contain Vowels
2. Program minta input string ke user -> inputUser = input("Please type in a string: ")
3. User ngasih input string ke program
4. Program ngolah inputan user, cek apakah ada huruf a, e, dan o
    4.1 if "a" in inputUser :
            print("a found")
        else:
            print("a not found")
    
    4.2 if "e" in inputUser :
            print("e found")
        else:
            print("e not found")
            
    4.3 if "o" in inputUser :
            print("o found")
        else:
            print("o not found")
5. Selesai
'''

# KODE FIKS

inputUser = input("Please type in a string: ")

if "a" in inputUser:
    print("a found")
else:
    print("a not found")
    
if "e" in inputUser:
    print("e found")
else:
    print("e not found")
    
if "o" in inputUser:
    print("o found")
else:
    print("o not found")
# Out:
# a found
# e found
# o not found

# %% [markdown]
# * The operator in returns a Boolean value, so it will only tell us if a substring exists in a string, but it will not be useful in finding out where exactly it is. Instead, the Python string method find can be used for this purpose. It takes the substring searched for as an argument, and returns either the first index where it is found, or -1 if the substring is not found within the string.
#
# * Jadi, method find di Python itu fungsinya buat nyari tau indeks dari substring tertentu yang ada di suatu string.
# Kemungkinan return-nya ada 2, yakni indeks huruf pertama dari suku kata yang diinput atau -1 kalo ternyata substringnya
# ngga ada di string.
#
# * Contoh:
# input_string = "test"
#
# print(input_string.find("t"))
# print(input_string.find("x"))
# print(input_string.find("es"))
# print(input_string.find("ets"))
#
# OUTPUT:
# 0
# -1
# 1
# -1
#
#
# input_string = "perpendicular"
#
# while True:
#     substring = input("What are you looking for? ")
#     index = input_string.find(substring)
#     if index >= 0:
#         print(f"Found it at the index {index}")
#     else:
#         print("Not found")
#
# OUTPUT:
# What are you looking for? perp
# Found it at the index 0
# What are you looking for? abc
# Not found
# What are you looking for? pen
# Found it at the index 3
# ...
#
# * Methods
# Above we used the string method find. Methods work quite similarly to the functions covered in the previous part. What distinguishes them from functions is that methods are always attached to the object they are called on. The object is the entity named before the method in the method call. In the case of find the object is the string where the method looks for the substring it has as an argument.
#
# * Perbedaan method dan function:
#     - function berdiri sendiri, method terikat pada objek
#     - method itu biasanya terkait sama perilaku objeknya (lebih spesifik), function lebih umum
#     - function untuk mengirim/mengembalikan data, method untuk mengolah data dari suatu kelas

# %%
# Programming Exercise :
# Find the first substring
'''
Please write a program which asks the user to type in a string and a single character. 
The program then prints the first three character slice which begins with the character specified by the user. 
You may assume the input string is at least three characters long. The program must print out three characters, 
or else nothing.

Pay special attention to when there are less than two characters left in the string after the 
first occurrence of the character looked for. In that case nothing should be printed out, 
and there should not be any indexing errors when executing the program.

Please type in a word: mammoth
Please type in a character: m
mam

Please type in a word: banana
Please type in a character: n
nan

Please type in a word: tomato
Please type in a character: x

Please type in a word: python
Please type in a character: n
'''

# KOTRETAN KASAR
'''
word = "kucing"
character = input("karakter: ")

indeksMulai = word.find(character)
if len(word) >= 3 and (len(word) - int(indeksMulai)) >= 3 :
    print(word[indeksMulai:(indeksMulai+3)])

OUTPUT:
uci
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Find the First Substring
2. Program minta input string ke user -> inputKata = input("Please type in a word: ")
    2.1 User ngasih input string inputKata ke program
3. Program minta input karakter ke user -> cariKarakter = input("Please type in a character: ")
    3.1 User ngasih input string karakter cariKarakter ke program
4. Program mengolah inputKata dan cariKarakter dari user
    4.1 definisikan variabel buat nyari tau dari string apa bakal diprint -> indeksMulai = word.find(cariKarakter)
    4.2 JIKA panjang karakter >= 3 (karena requirement-nya minimal 3) dan panjang string word - indeksMulai  >= 3 
        (ini buat handling ketika diinputnya di dua string terakhir dia gabakal ngehasilin output apa apa meskipun karakternya ada, jadi minimal di 3 string terakhir baru bisa ada outpunya)
    4.3 PRINT (inputKata [indeksMulai : (indeksMulai + 3)]) -> bakal ngeprint dari karakter pertama yang kedetect sampai 2 string selanjutnya (outputnya pokoknya ada 3 karakter)
5. Selesai
'''

# KODE FIKS
inputKata = input("Please type in a word: ")
cariKarakter = input("Please type in a character: ")

indeksMulai = inputKata.find(cariKarakter)
if len(inputKata) >= 3 and (len(inputKata) - indeksMulai) >= 3:
    print(inputKata [ indeksMulai : (indeksMulai + 3) ])
# Out:
# alo

# %%
# Programming Exercise :
# Find all the substrings
'''
Please make an extended version of the previous program, which prints out all the substrings which are 
at least three characters long, and which begin with the character specified by the user. 
You may assume the input string is at least three characters long.

Please type in a word: mammoth
Please type in a character: m
mam
mmo
mot

Please type in a word: banana
Please type in a character: n
nan

Hint the following example may give you some inspiration as to how this exercise could be tackled:
word = input("Word: ")
while True:
    if len(word) == 0:
        break
    print(word)
    word = word[2:]

Word: mammoth
mammoth
mmoth
oth
h
'''

# KOTRETAN KASAR
'''
word = "mammothhmhmh"
karakter = "m"
indeksMulai = word.find("m")


while True:
    if word[indeksMulai] == "m" and len(word) >= 3 and (len(word) - indeksMulai) >= 3:
        print(word[indeksMulai:indeksMulai + 3])
    indeksMulai += 1
    if indeksMulai == len(word):
        break
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Find all the substrings
2. Program minta input string ke user -> inputKata = input("Please type in a word: ")
    2.1 User input string inputKata ke program
3. Program minta input karakter ke user -> cariKarakter = input("Please type in a character: ")
    3.1 User input string cariKarakter ke program
4. Program mengolah inputKata dan cariKarakter hasil inputan user
    4.1 definisikan indeksMulai = word.find(inputKarakter) -> yakni indeks karakter yang diinput user, 
    sebagai penanda kalo itu nanti jadi substring pertama 
    4.2 WHILE TRUE :  -> biar bisa nyari terus secara otomatis substring yang bisa diprint
            JIKA inputKata[indeksMulai] = m dan panjang karakter word >= 3 dan panjang karakter word - indeks mulai >= 3:  -> (ini kondisi biar programnya
            hanya bakal jalan kalo karakter pertama dari substring huruf m, kalo panjang karakter inputKata >= 3, DAN kalo panjang karakter inputKata dikurangi indeksMulai >=3, jadi yang substringnya berjumlah 2 karakter ga akan keprint)
                print(inputKata[indeksMulai:indeksMulai+3]) -> ngeprint substring
            indeksMulai += 1 -> biar bisa ngecek semua substring yang ada di inputKata secara otomatis
            if indeksMulai == len(inputKata) -> buat ngesolve eror out of index.  karena kalo ga di break pake ini, nanti pas akhir ketika indeksMulainya lebih besar dari inputKata bakal out of index.
                break
5. Selesai
'''

# KODE FIKS
inputKata = input("Please type in a word: ")
cariKarakter = input("Please type in a character: ")

indeksMulai = inputKata.find(cariKarakter)

while True:
    if inputKata[indeksMulai] == cariKarakter and len(inputKata) >= 3 and len(inputKata) - indeksMulai >= 3:
        print(inputKata[indeksMulai : indeksMulai + 3])
    indeksMulai += 1
    if indeksMulai == len(inputKata):
        break
# Out:
# mam
# mmo
# mot

# %% [markdown]
# End Selasa, 11 Februari 2025, 12:12 AM, Sampai Programming Exercise Find all the substrings

# %% [markdown]
# Start Rabu, 12 Februari 2025, 08:20 PM
# Start lagi Jumat, 14 Februari 2025, 11:01 PM (belum ke-solve)

# %%
# Programming Exercise :
# The second occurrence
'''
Please write a program which finds the second occurrence of a substring. If there is no second (or first) occurrence, 
the program should print out a message accordingly.

In this exercise the occurrences cannot overlap. 
For example, in the string aaaa the second occurrence of the substring aa is at index 2.

Some examples of expected behaviour:

Please type in a string: abcabc
Please type in a substring: ab
The second occurrence of the substring is at index 3.

Please type in a string: methodology
Please type in a substring: o
The second occurrence of the substring is at index 6.

Please type in a string: aybabtu
Please type in a substring: ba
The substring does not occur twice in the string.
'''

# KOTRETAN KASAR
'''
inputString = input("Please type in a string: ")
substringPertama = input("Please type in a substring: ")
iterasi = 0




'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Find all the substrings
2. Program minta input kata ke user -> inputString = input("Please type in a string: ")
    2.1 User ngasih input inputString ke program
3. Program minta input substring yang mau dicari ke user -> inputSubstring = input("Please type in a substring: ")
    3.1 User ngasih input inputSubstring ke program
4. Program mengolah inputan user

misal indeksAwal = 4
terus abis iterasi 2 nemu lagi tuh substring yang sama
nah berarti second occurence ada di index 6.

berarti kita perlu catet berapa iterasinya, abis itu ditambah dengan indeks awal    
    
5. Selesai
'''

# KODE FIKS

# Please type in a string: abcabc
# Please type in a substring: ab
# The second occurrence of the substring is at index 3.

# Please type in a string: methodology
# Please type in a substring: o
# inputString[indeksAwal] -> methodology[4]
# inputString.find(inputSubstring) -> indeks[4]


# The second occurrence of the substring is at index 6.

# Please type in a string: aybabtu
# Please type in a substring: ba
# The substring does not occur twice in the string.


# KODE FIKS
'''
inputKata = input("Please type in a word: ")
cariKarakter = input("Please type in a character: ")

indeksMulai = inputKata.find(cariKarakter)

while True:
    if inputKata[indeksMulai] == cariKarakter and len(inputKata) >= 3 and len(inputKata) - indeksMulai >= 3:
        print(inputKata[indeksMulai : indeksMulai + 3])
    indeksMulai += 1
    if indeksMulai == len(inputKata):
        break
'''

# inputString = input("Please type in a string: ")
# substring = input("Please type in a substring: ")
inputString = "halohalo"
substring = "al"
iterasi = 0
jumlahKemunculan = 0

while True:
    if substring[0] == inputString[iterasi]:
        jumlahKemunculan += 1
        iterasSubstringMuncul = iterasi
        if jumlahKemunculan == 2:
            print(f"The second substring is on the {iterasi} index")
    iterasi += 1
    if iterasi == len(inputString):
        break
# Out:
# The second substring is on the 5 index

# %%
inputString = input("Please type in a string:")
substring = input("Please type in a substring:")
iterasi = 0
jumlahKemunculan = 0

while True:
    if iterasi <= len(inputString) - 1:
        if substring[0] == inputString[iterasi]:
            jumlahKemunculan += 1
            iterasiSubstringMuncul = iterasi
            if jumlahKemunculan == 2:
                print(f"The second occurrence of the substring is at index {iterasiSubstringMuncul}.")
                break
        iterasi += 1
        if iterasi <= len(inputString) - 1 and jumlahKemunculan == 0:
            print("The substring does not occur twice in the string.")
            break
# Out:
# The substring does not occur twice in the string.

# %% [markdown]
# Start Sabtu, 15 Februari 2025, 04:30 PM
#
# # Part 3 - More Loops
#
# * Learning objectives
# After this section
#
# You will understand when the break command is needed to break out of loops
# You will be able to use the continue command to move to the next iteration
# You will understand how nested loops work
#
# * The break command
# You have already come across the break command. It can be used to stop the execution of a loop immediately. A typical example of where it is used is a situation where the program asks the user for input, and the execution ends only when a specific input is received.
#
# The same functionality can be achieved without the break command, using a suitable condition. The two programs below both ask the user to type in numbers, and calculate the sum of the numbers until the user types in -1.
#
# * 1st version using the break command
#
# sum = 0
#
# while True:
#     number = int(input("Please type in a number, -1 to exit: "))
#     if number == -1:
#         break
#     sum += number
#
# print (f"The sum is {sum}")
#
# * 2nd version without the break command
#
# sum = 0
# number = 0
#
# while number != -1:
#     number = int(input("Please type in a number, -1 to exit: "))
#     if number != -1:
#         sum += number
#
# print (f"The sum is {sum}")
# Both programs print out the same thing w
#
# * Both programs print out the same thing with the same inputs, for example:
#
# Please type in a number, -1 to exit: 2
# Please type in a number, -1 to exit: 4
# Please type in a number, -1 to exit: 5
# Please type in a number, -1 to exit: 3
# Please type in a number, -1 to exit: -1
# The sum is 14
#
# * So, the two programs are functionally practically identical. However, the first method is often easier, as the condition number == -1 appears only once, and the variable number doesn't have to be initialised outside the loop.
#
# The break command and a suitable condition can also be used together in a while loop. For example, the following loop is repeated as long as the sum of the numbers is at most 100, but it also stops if the user types in the number -1.
#
# * sum = 0
#
# while sum <= 100:
#     number = int(input("Please type in a number, -1 to exit: "))
#     if number == -1:
#         break
#     sum += number
#
# print (f"The sum is {sum}")
#
# * Some examples of the program's execution:
#
# Please type in a number, -1 to exit: 15
# Please type in a number, -1 to exit: 8
# Please type in a number, -1 to exit: 21
# Please type in a number, -1 to exit: -1
# The sum is 44
#
# Please type in a number, -1 to exit: 15
# Please type in a number, -1 to exit: 8
# Please type in a number, -1 to exit: 21
# Please type in a number, -1 to exit: 45
# Please type in a number, -1 to exit: 17
# The sum is 106
#
# In the first example the execution of the loop stops because the user types in the number -1. In the second example it stops because the sum of the numbers exceeds 100.
#
# * As always in programming, there are many ways to reach the same functionality. The following program is functionally identical to the above:
#
# sum = 0
#
# while True:
#     number = int(input("Please type in a number, -1 to exit: "))
#     if number == -1:
#         break
#     sum += number
#     if sum > 100:
#         break
#
# print (f"The sum is {sum}")\
#
# * The continue command
# Another way to change the way a loop is executed is the continue command. It causes the execution of the loop to jump straight to the beginning of the loop, where the condition of the loop is. Then the execution continues normally with checking the condition:
#
# * For example, the following program sums up numbers from input, but it only includes the numbers which are smaller than 10. If the number is 10 or greater, the execution jumps to the beginning of the loop and the number is not added to the sum.
#
# sum = 0
#
# while True:
#     number = int(input("Please type in a number, -1 to exit: "))
#     if number == -1:
#         break
#     if number >= 10:
#         continue
#     sum += number
#
# print (f"The sum is {sum}")
#
# Sample output
# Please type in a number, -1 to exit: 4
# Please type in a number, -1 to exit: 7
# Please type in a number, -1 to exit: 99
# Please type in a number, -1 to exit: 5
# Please type in a number, -1 to exit: -1
# The sum is 16
#
#
# * Nested loops
# Just like if statements, loops can also be placed inside other loops. For example, the following program uses a loop to ask the user to input numbers. It then uses another loop inside the first one to print a countdown from the given number down to 1:
#
# while True:
#     number = int(input("Please type in a number: "))
#     if number == -1:
#         break
#     while number > 0:
#         print(number)
#         number -= 1
#
# Please type in a number: 4
# 4
# 3
# 2
# 1
# Please type in a number: 3
# 3
# 2
# 1
# Please type in a number: 6
# 6
# 5
# 4
# 3
# 2
# 1
# Please type in a number: -1
#
#
# * When there are nested loops, break and continue commands only affect the innermost loop which they are a part of. The previous example could also be written like this:
#
# while True:
#     number = int(input("Please type in a number: "))
#     if number == -1:
#         break
#     while True:
#         if number <= 0:
#             break
#         print(number)
#         number -= 1
#
# Here the latter break command only stops the innermost loop, which is used to print the numbers.
#
# * More helper variables with loops
# We've already used helper variables, which increase or decrease with every iteration of a loop, many times before, so the following program should look quite familiar in structure. The program prints out all even numbers above zero until it reaches a limit set by the user:
#
# limit = int(input("Please type in a number: "))
# i = 0
# while i < limit:
#     print(i)
#     i += 2
#
# Please type in a number: 8
# 0
# 2
# 4
# 6
#
# The helper variable i is set to 0 before the loop, and it increases by two with every iteration.
#
# * Using nested loops sometimes necessitates a separate helper variable for the inner loop. The program below prints out a "number pyramid" based on a number given by the user:
#
# number = int(input("Please type in a number: "))
# while number > 0:
#     i = 0
#     while i < number:
#         print(f"{i} ", end="")
#         i += 1
#     print()
#     number -= 1
#
# Please type in a number: 5
# 0 1 2 3 4
# 0 1 2 3
# 0 1 2
# 0 1
# 0
#
# * In this program the outer loop uses the helper variable number, which decreases by 1 with each iteration until it reaches 0. The helper variable i is set to 0 just before the inner loop is entered, each time the outer loop repeats.
#
# * The inner loop uses the helper variable i, which increases by 1 with each iteration of the inner loop. The inner loop repeats until i is equal to number, and prints out each value of i on the same line, separated by a space character. When the inner loop finishes, the print command in the outer loop starts a new line.
#
# * Now remember that with each iteration of the outer loop the value of number decreases, so the amount of times the inner loop repeats also decreases. With each repetition the line of numbers gets shorter, and thus we get the pyramid shape.
#
# * Nested loops can get confusing fast, but understanding the way they work is essential. You may well find the Python Tutor visualisation tool helpful in understanding how this example works. Copy the above code into the code window of the tool and follow the formation of the printout and the changing values of the helper variables as the execution progresses.

# %%
# Programming Exercise :
# Multiplication
'''
Please write a program which asks the user for a positive integer number. The program then prints out a list of multiplication operations 
until both operands reach the number given by the user. See the examples below for details:

Please type in a number: 2
1 x 1 = 1
1 x 2 = 2
2 x 1 = 2
2 x 2 = 4

Please type in a number: 3
1 x 1 = 1
1 x 2 = 2
1 x 3 = 3
2 x 1 = 2
2 x 2 = 4
2 x 3 = 6
3 x 1 = 3
3 x 2 = 6
3 x 3 = 9


'''

# KOTRETAN KASAR
'''
inputNumber = int(input("Please type in a number: "))
iterasiGlobal = 1
iterasiLokal = 1
hasil = inputNumber**2
hasilKali = 0

while hasilKali != hasil:
    while iterasiGlobal <= inputNumber:
        hasilKali = iterasiGlobal * iterasiLokal
        print(f"{iterasiGlobal} x {iterasiLokal} = {hasilKali}")
        iterasiLokal += 1
        if iterasiLokal - 1 == inputNumber:
            iterasiLokal = 1
            break
    iterasiGlobal += 1
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Multiplication
2. Definisikan variabel buat looping angka yang di depan nantinya -> iterasiGlobal = 1 (biar iterasinya mulai dari 1, bukan 0)
3. Definisikan variabel buat looping angka yang di belakang nantinya -> iterasILokal = 1 (biar iterasinya mulai dari 1, bukan 0)
4. Definisikan variabel hasil -> hasil = inputNumber**2 (karena ini adalah hasil paling maksimal yang bisa didapat)
5. Definisikan variabel hasilKali = 0 -> hasilKali = 0 (buat ngasih nilai awalan aja)
6. Program minta input angka integer dari user -> inputNumber = int(input("Please type in a number: ")) -> harusnya di awal aja gapapa biar langsung dapet variabel inputNumber-nya
7. User ngasih inputNumber ke program
8. Program mengolah inputan inputNumber dari user
    8.1 Jadi, karena di sini kan outputnya diharapkan ada angka pengali (yang di belakang) dan yang dikali (yang di depan), kita liat polanya, 
        si yang dikali itu bakal terus sama di tiap siklus angka, misal pas perkalian angka 1, si angka yang dikali tetep 1, ngga berubah.  Sedangkan bilangan yang
        jadi pengali nambah 1 tiap iterasi.  Nah, bilangan yang dikaliin baru berubah ketika iterasi tiap jenis angkanya beres, dan begitu seterusnya.  Makanya,
        dibutuhkan dua while loop biar bisa mengakomodasi kedua perubahan itu.
        Dalam hal ini, si pengali diwakilkan oleh variabel iterasiLokal.  Sedangkan si dikali diwakilkan oleh iterasiGlobal.  Lokal -> lebih kecil skalanya, lebih cepat berubah
    8.2 WHILE hasil perkalian antara iterasiGlobal dan iterasiLokal != hasil (artinya bakal ngeloop terus selama hasil perkaliannya belum mentok 
        sampe yang terbesar.  karena artinya kalo hasil perkaliannya udah mentok, programnya udah beres.):
            8.3 WHILE iterasiGlobal  <= inputNumber -> Artinya, ketika angka yang dikali masih kurang dari atau sama dengan input angka dari user, program jalan terus:
                8.4 definisikan variabel hasilKali = iterasiGlobal * iterasiLokal -> ini bakal jadi hasil perkalian tiap iterasi
                8.5 print iterasiGlobal * iterasiLokal = hasilKali -> tampilin si pengali, yang dikali, dan hasil perkalian keduanya (beres nih satu iterasi lokal)
                8.6 Increment si iterasiLokal -> biar apa?  biar si pengali nambah, dari 1 ke 2, dari 2 ke 3... (nanti masuk ke iterasi ke-2, ke-3, dst..)
                    8.7 Bikin IF conditional -> JIKA iterasiLokal - 1 == inputNumber (Kan nanti iterasiLokal bakal increment terus nih, kita harus ngebatesin dong biar pada titik tertentu, dia ngereset lagi dari 1 buat next iterasiGlobal.
                        nah, makanya disini ketika iterasiLokal-nya udah sama kaya inputNumbernya, dia direset lagi ke 1.  Tapi kenapa iterasiLokal - 1?  kenapa harus dikurangi 1 dulu?
                        karena kalo kita lihat, persis di atasnya ini kan ada kode yang buat nge increment si iterasiLokal tuh yang iterasiLokal += 1, bayangin sebenernya 
                        kan iterasiLokal yang nilainya sama kaya inputNumber harus tetep masuk di perkalian, misal udah sama sama 3 nih, mau ga mau kan dia
                        nanti harus ngalamin si increment yang dibawahnya lagi.  Makanya, harus kita kurangin sama satu buat NGENETRALIN lagi.).  Nah pas setelah ini kita break biar bisa keluar dari loop itu dan increment iterasiGlobal dulu.
                8.7 Nah, abis beres satu iterasiLokal, gantianlah si iterasiGlobal (angka yang dikali) yang increment -> iterasiGlobal += 1.
                8.8 Nanti bakal mengulangi lagi siklus yang 8.6, bedanya misal tadi awalnya 1x1, 1x2, 1x3 (angka yang dikalinya/iterasiGlobal-nya == 1), sekarang jadi
                    2x1, 2x2, 2x3 (angka yang dikalinya/iterasiGlobal-nya == 2).  Siklus ini bakal mengulang SAMPAI iterasiGlobal-nya sama dengan inputNumber (udah mentok)
9. Selesai
'''

# KODE FIKS
inputNumber = int(input("Please type in a number: "))
iterasiGlobal = 1
iterasiLokal = 1
hasil = inputNumber ** 2
hasilKali = 0

while hasilKali != hasil:
    while iterasiGlobal <= inputNumber:
        hasilKali = iterasiGlobal * iterasiLokal
        print(f"{iterasiGlobal} x {iterasiLokal} = {hasilKali}")
        iterasiLokal += 1
        if iterasiLokal - 1 == inputNumber:
            iterasiLokal = 1
            break
    iterasiGlobal += 1
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# ...

# %%
# Programming Exercise :
# First letters of words
'''
Please write a program which asks the user to type in a sentence. The program then prints out the first letter of each word in the sentence, each letter on a separate line.

An example of expected behaviour:

Please type in a sentence: Humpty Dumpty sat on a wall
H
D
s
o
a
w
'''

# KOTRETAN KASAR
# inputKalimat = input("Please type in a sentence: ")
'''
inputKalimat = "Halo tes 123"
iterasi = 0

print(inputKalimat[0])
while iterasi <= len(inputKalimat):
    if " " in inputKalimat[iterasi]:
        print(iterasi)
        print(inputKalimat[iterasi+1])
    iterasi += 1
    if iterasi == len(inputKalimat):
        break

OUTPUT :
H
4
t
8
1
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program First Letters of Words
2. Program minta input kalimat ke user -> inputKalimat = input("Please type in a sentence: ")
3. Definisikan variabel iterasi = 0 -> buat ngasih nilai awalan aja karena nanti di awal-awal loop bakal dipakai, kalo ga didefinisiin dulu gabisa
4. Print dulu huruf pertama dari inputKalimat sebelum masuk ke loop -> print(inputKalimat[0])
5. WHILE iterasi <= len(inputKalimat): -> Bakal ngulang terus SELAMA nilai dari iterasi masih kurang dari atau sama dengan panjang karakter.  Artinya dia bakal terus ngecek setiap huruf di setiap iterasinya.
    5.1 IF " " in inputKalimat[iterasi]: -> kan kita mau ngeprint setiap karakter persis setelah spasi, makanya kita pake parameter spasi buat basisnya.  di setiap iterasinya, kita
        cek apakah karakternya spasi atau bukan?  kalo bukan, maka cek lagi karakter selanjutnya.  
        5.12 kalo IYA, maka kita print 1 karakter persis setelah letak si spasi tersebut (1 karakter setelah iterasi) ->  print(inputKalimat[iterasi + 1])
    5.2 Increment si iterasi -> iterasi += 1 (karena kita kan mau ngecek setiap karakter, jadi iterasinya harus nambah 1 setiap siklus)
    5.3 IF nilai iterasi udah sama dengan panjang karakter (udah mentok semua karakter inputKalimat diiterasi, apa lagi yang mau dicek?), maka break program (exit)
6. Selesai
'''

# KODE FIKS
inputKalimat = input("Please type in a sentence: ")
iterasi = 0

print(inputKalimat[0])

while iterasi <= len(inputKalimat):
    if " " in inputKalimat[iterasi]:
        print(inputKalimat[iterasi + 1])
    iterasi += 1
    if iterasi == len(inputKalimat):
        break

# Contoh input misalnya:
# Lorem ipsum Dolor Sit 4met
# Out:
# L
# i
# D
# S
# 4

# %% [markdown]
# End Sabtu, 15 Februari 2025, 11:20 PM, Sampai programming exercise First Letters of Words

# %% [markdown]
# Start Minggu, 16 Februari 2025, 11:35 PM,

# %%
# Programming Exercise :
# Factorial
'''
Please write a program which asks the user to type in an integer number. If the user types in a number equal to or below 0, the execution ends. 
Otherwise the program prints out the factorial of the number.

The factorial of a number involves multiplying the number by all the positive integers smaller than itself. 
In other words, it is the product of all positive integers less than or equal to the number. For example, the factorial of 5 is 1 * 2 * 3 * 4 * 5 = 120.

Some examples of expected behaviour:

Please type in a number: 3
The factorial of the number 3 is 6
Please type in a number: 4
The factorial of the number 4 is 24
Please type in a number: -1
Thanks and bye!

Please type in a number: 1
The factorial of the number 1 is 1
Please type in a number: 0
Thanks and bye!
'''

# KOTRETAN KASAR
'''
'''

# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Factorial
2. Definisikan variabel iterasi -> iterasi = 0 (buat ngasih nilai awalan)
3. Definisikan variabel inputAngka -> inputAngka = 1 (buat ngasih nilai awalan biar bisa dipake di WHILE Conditional)
4. WHILE inputAngka > 0:  -> biar kalo user input angkanya 0 atau kurang dari 0, program otomatis berhenti.
    4.2 inputAngka = Masukkan Angka : -> minta input angka integer ke user
    4.3 WHILE inputAngka > iterasi : -> program bakal jalan kalo angka yang diinput > 0:
        4.3.1 hasilPerkalian = hasilPerkalian * (iterasi + 1) -> buat menyimpan hasil perkaliannya -> hasilPerkalian = 1 * (0 + 1) = 1; hasilPerkalian = 1 * (1 + 1) = 2; hasilPerkalian = 2 * (2 + 1) = 6; dst...
        4.3.2 iterasi += 1  -> biar pengalinya nambah
        4.4 IF iterasi == inputAngka :  -> kasih batas biar ngga jadi forever loop
            4.4.1 print(faktorialnya dari angka yang diinput user adalah hasilPerkalian)
            4.4.2 iterasi = 0 -> biar iterasinya ngereset lagi dari 0
            4.4.3 hasilPerkalian = 1 -> biar hasilPerkaliannya ngereset lagi dari 1
            4.4.4 break -> beres, lanjut lagi ke loop yang parentnya (while inputAngka > 0)
5. print("Thanks and bye!") -> Kalo ga sesuai sama WHILE inputAngka > 0: , yakni ketika user masukin angka yang <= 0, program bakal keluar dari loop dan ngeprint ini 
6. Selesai
'''

# KODE FIKS
iterasi = 0
inputAngka = 1
while inputAngka > 0:
    inputAngka = int(input("Please type in a number: "))
    while inputAngka > iterasi:
        hasilPerkalian = hasilPerkalian * (iterasi + 1)
        iterasi += 1
        if iterasi == inputAngka:
            print(f"The factorial of the number {inputAngka} is {hasilPerkalian}")
            iterasi = 0
            hasilPerkalian = 1
            break
print("Thanks and bye!")
# Out:
# The factorial of the number 5 is 120
# The factorial of the number 4 is 24
# The factorial of the number 3 is 6
# The factorial of the number 2 is 2
# The factorial of the number 1 is 1
# The factorial of the number 10 is 3628800
# The factorial of the number 3 is 6
# The factorial of the number 4 is 24
# The factorial of the number 5 is 120
# Thanks and bye!

# %% [markdown]
# End Senin, 17 Februari 2025, 12:07 AM

# %% [markdown]
# Start Senin, 17 Februari 2025, 11:10 PM

# %%
# Programming Exercise :
# Flip the pairs
'''
Please write a program which asks the user to type in a number. The program then prints out all the positive integer values from 1 up to the number. 
However, the order of the numbers is changed so that each pair or numbers is flipped. That is, 2 comes before 1, 4 before 3 and so forth. See the examples below for details.

Please type in a number: 5
2
1
4
3
5

Please type in a number: 6
2
1
4
3
6
5
'''

# KOTRETAN KASAR
'''
inputAngka = int(input("Please type in a number: "))
iterasi = 1

while iterasi <= inputAngka:
    if inputAngka % 2 != 0:
        while iterasi < inputAngka:
            if iterasi % 2 == 0:
                print(f"{iterasi - 1}")
            elif iterasi % 2 != 0:
                print(f"{iterasi + 1}")
            iterasi += 1
        print(f"{inputAngka}")
        break
    elif inputAngka % 2 == 0:
        while iterasi <= inputAngka:
            if iterasi % 2 == 0:
                print(f"{iterasi - 1}")
            elif iterasi % 2 != 0:
                print(f"{iterasi + 1}")
            iterasi += 1
'''


# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Flip the Pairs
2. Program minta input angka integer ke user -> inputAngka = int(input("Please type in a number: "))
3. Definisikan variabel iterasi, buat keperluan ngeprint-ngeprintnya nanti karena butuh tau di posisi mana angkanya -> iterasi = 1 ; kenapa 1? biar intuitif, angka pertama indeksnya 1, angka kedua indeksnya 2, dst.
4. WHILE iterasi <= inputAngka :  -> kondisi biar SELAMA iterasinya masih kurang dari atau sama dengan inputAngka, program ngeloop terus
    4.1 IF inputAngka % 2 != 0:  -> karena ada perbedaan perlakuan ternyata antara inputAngka yang ganjil dan genap.  Kalo ganjil, angka terakhir yang diprint adalah si inputAngka, padahal kan kalo ngikutin aturan harusnya inputAngka + 1 (dari yang besar dulu) 
        4.1.1 WHILE iterasi < inputAngka: -> ini ibaratnya local loopingnya yang memungkinkan semua angkanya ke-print.  selama iterasinya masih <= inputAngka, program jalan terus
                4.1.2 IF iterasi % 2 == 0: -> kan kebalik ya yang iterasi 1 ngeprintnya 2, iterasi 2 ngeprintnya 1.  Makanya kalo iterasi dia ganjil, berarti print iterasi ditambah 1.  Kalo genap iterasinya, berarti yang diprint si iterasi tsb dikurang 1
                        4.1.3 print iterasi-1
                4.1.4 ELIF iterasi % 2 != 0:
                        4.1.5 print iterasi+1
                4.1.6 iterasi += 1
        4.1.7 print inputAngka -> kan while loopnya beres di inputAngka - 1, abis itu keluar langsung ke sini, ngeprint inputAngka. biar yang keprint bukan inputAngka + 1
        4.1.8 break -> program beres
    4.2 ELIF inputAngka % 2 == 0: -> kondisi ketika angkanya genap
        4.2.1 WHILE iterasi <= inputAngka : -> kenapa kurang dari atau sama dengan?  kok beda sama while loop sebelumnya yang kurang dari aja?  karena kalo di sini kita flow aja ngikutin program.  kalo sebelumnya kan kita pengen biar di akhir ngeprint sesuai yang kita mau, yakni si inputAngka
                4.2.2 IF iterasi % 2 == 0:
                        4.2.3 print iterasi - 1
                4.2.4 ELIF iterasi % 2 != 0:
                        4.2.5 print iterasi + 1  -> kedua IF dan ELIF ini bertujuan biar pas iterasi ke-1, angka yang diprint adalah 2; pas iterasi ke-2, angka yang diprint adalah 1, dan seterusnya menggunakan parameter ganjil-genap dari posisi angka yang diwakili oleh variabel iterasi.
                4.2.6 iterasi += 1 -> increment iterasi
5. Selesai
'''

# KODE FIKS
inputAngka = int(input("Please type in a number: "))
iterasi = 1

while iterasi <= inputAngka:
    if inputAngka % 2 != 0:
        while iterasi < inputAngka:
            if iterasi % 2 == 0:
                print(f"{iterasi - 1}")
            elif iterasi % 2 != 0:
                print(f"{iterasi + 1}")
            iterasi += 1
        print(f"{inputAngka}")
        break
    elif inputAngka % 2 == 0:
        while iterasi <= inputAngka:
            if iterasi % 2 == 0:
                print(f"{iterasi - 1}")
            elif iterasi % 2 != 0:
                print(f"{iterasi + 1}")
            iterasi += 1
# Out:
# 2
# 1
# 4
# 3
# 6
# 5
# 8
# 7
# 10
# 9

# %%
# Programming Exercise :
# Taking Turns
'''
Please write a program which asks the user to type in a number. The program then prints out the positive integers between 1 and the number itself, 
alternating between the two ends of the range as in the examples below.

Please type in a number: 5
1
5
2
4
3

Please type in a number: 6
1
6
2
5
3
4
'''

# KOTRETAN KASAR
'''
# inputAngka = int(input("Please type in a number: "))
# iterasi = 1
# pengurang = 1

# while iterasi < inputAngka + 2 :
#     while iterasi <= inputAngka + 2:
#         if iterasi % 2 != 0:
#             pengurang += 1
#             print(f"{iterasi - (1 * pengurang) + 2}")
#         if iterasi % 2 == 0:
#             print (inputAngka)
#             inputAngka -= 1
#         iterasi += 1

        
        # iterasi 2 - 0
        # iterasi 3 -1
        # iterasi 5 - 2
        # iterasi 7 - 3

# 1   -> iterasi 1 = 1  -> 1 - (0)
# 10  -> iterasi 2 = 10 
# 2   -> iterasi 3 = 2  -> 3 - (0 + 1)
# 9   -> iterasi 4 = 9  
# 3   -> iterasi 5 = 3  -> 5 - (0 + 1 + 1)
# 8   -> iterasi 6 = 8
# 4   -> iterasi 7 = 4  -> 7 - (0 + 1 + 1 + 1)
# 7   -> iterasi 8 = 7  
'''


# ALGORITMA / PSEUDOCODE
'''
1. Mulai program Taking Turns
2. inputAngka = int(input("Please type in a number: ")) -> program minta input angka integer ke user
3. iterasi = 1 -> definisikan variabel iterasi buat mewakili posisi angka.  aslinya bisa pake index cuman karena indeks mulai dari 0 jadi kurang intuitif.
4. while iterasi <= inputAngka : -> program jalan terus selama iterasi <= inputAngka
    4.1 while iterasi <= inputAngka: -> program jalan terus selama iterasi <= inputAngka (kok diulang?  iya sebenernya yang penting yang di sini, yang atas bisa diganti sama while True aja.
        4.1.1 jika iterasi ke-1 (ganjil):
                print iterasi (dari angka terkecil)
                iterasi += 1
        4.1.2 jika iterasi ke-2 (genap):
                print inputAngka (dari angka terbesar)
                iterasi += 1
                inputAngka -= 1
5. Selesai

REVISI
1. bikin variabel inputAngka (input angka user), iterasi (buat nandain lagi di posisi mana), 
   pengurang (ini buat kondisi ketika iterasinya genap, makin tinggi iterasi, makin tinggi pengurang), 
   dan batas (buat mengisi kekosongan si inputAngka karena setiap iterasi genap, inputAngka-nya selalu berkurang). -> 
   kenapa ga pake iterasi aja?  karena increment iterasi terjadi pada kedua kondisi IF, sedangkan kan kita mau cari yang berkaitan sama inputAngka aja
2. KETIKA iterasi kurang dari atau sama dengan inputAngka ditambah batas dikurangi satu, jalankan IF CONDITIONAL
3. IF iterasi bersifat genap, THEN print inputAngka, increment inputAngka dengan 1, increment batas dengan 1, increment iterasi dengan 1.  Lalu progran berlanjut dari atas lagi selama iterasi <= inputAngka + batas - 1
4. ELIF iterasi bersifat ganjil, THEN print iterasi dikurangi pengurang, increment pengurang dengan 1, increment iterasi dengan 1 
5. Ketika iterasi sudah sama dengan inputAngka ditambah batas, program otomatis berhenti
'''

# KODE FIKS
inputAngka = int(input("Please type in a number: "))
iterasi = 1
pengurang = 0
batas = 0

while iterasi <= inputAngka + batas:
    if iterasi % 2 == 0:
        print(f"{inputAngka}")
        inputAngka -= 1
        batas += 1
        iterasi += 1
    elif iterasi % 2 != 0:
        print(f"{iterasi - pengurang}")
        pengurang += 1
        iterasi += 1
# Out:
# 1
# 7
# 2
# 6
# 3
# 5
# 4
